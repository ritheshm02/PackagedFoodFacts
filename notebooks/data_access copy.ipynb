# %% [markdown]
# #### Access product

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score
import joblib
import numpy as np

# Load the dataset
file_path = 'cleaned_data4.csv'
df = pd.read_csv(file_path)
# Out:
# C:\Users\sbk74\AppData\Local\Temp\ipykernel_14560\3618168070.py:10: DtypeWarning: Columns (0,40,42,44,46,48,58,60,62,64,66,68,80,82,84,88,90,92,94,96,100,106,110,114,118,122,126,130,134,136,138,140,144,146,148,150,152,154,156,166,172,176,180,184,188,190,194,196,198,200,202,206,210,212,214,216,220,222,223) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)

# %%
# Assuming 'df' is your existing DataFrame
# Create a new column 'health_label' with NaN values
df['health_label'] = np.nan

# If you prefer to initialize with an empty string or another placeholder
# df['health_label'] = ''  # For an empty string
# df['health_label'] = 'Unknown'  # For a custom placeholder

print(df.columns)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 9
#       3 df['health_label'] = np.nan
#       5 # If you prefer to initialize with an empty string or another placeholder
#       6 # df['health_label'] = ''  # For an empty string
#       7 # df['health_label'] = 'Unknown'  # For a custom placeholder
# ----> 9 print(df.columns())
#
# TypeError: 'Index' object is not callable
